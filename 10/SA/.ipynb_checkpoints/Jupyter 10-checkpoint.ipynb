# %% [markdown]
# # Esercitazione 10
# # SA

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

#input file
N=500
l2_b = np.zeros(N)
file_data = np.loadtxt('BsL1.out', usecols=(1))
l2_b = file_data[:]


plt.plot(i,l2_b)
plt.title('$L^{(2)}$')
plt.legend(['Best','Best Half'], loc='best')
plt.xlabel('i')
plt.ylabel('l2')
#plt.ylim([2,3])
plt.savefig('Pictures/square_l2', dpi=300)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-167049a05cf8> in <module>
#      11
#      12
# ---> 13 plt.plot(i,l2_b)
#      14 plt.title('$L^{(2)}$')
#      15 plt.legend(['Best','Best Half'], loc='best')
#
# NameError: name 'i' is not defined

# %%
Nct=32
x = np.zeros(Nct)
y = np.zeros(Nct) 
file_data = np.loadtxt('BsPath.out', usecols=(0,1))
x = file_data[:,0]
y = file_data[:,1]

plt.plot(x,y)
plt.title('Best Path')
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('Pictures/square_bspath', dpi=300)
plt.grid(True)
plt.show()

# %% [markdown]
# # 32 città su una circonferenza
